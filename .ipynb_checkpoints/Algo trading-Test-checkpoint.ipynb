# %% [markdown]
# ### Required activity 25.3: Portfolio project on optimising a model for real-life data
#
# This project will be built with aim of predicting stock prices using Long Short Term Memory (LSTM).

# %% [markdown]
# ### Part 1. Finding a dataset
#
# 1. What format is the data in? Dates and numeric
#
# 2. Is the data clean? Yes, data downloaded from Yahoo! are cleaned.
#
# 3. How large is the dataset? Sizable data since 1980.
#
# 4. How will you split your data into train, validate and test sets? 60%, 20%, 20%

# %%
# Testing
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import seaborn as sb
import datetime
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta

now = datetime.now().date()
start = now - timedelta(days=90)

# %% [markdown]
# For simplicity sake, we will be using just Tesla stock.

# %%
# 1. Fetch Historical Stock Prices
data = yf.download('TSLA', start=start)
data = data[['Close']]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### Part 2. Exploratory Data Analysis (EDA)
# 1. Explore, clean and pre-process
# 2. Dimension reduction & feature engineering

# %%
nasdaq = yf.Ticker("^IXIC")
sp500 = yf.Ticker("^GSPC")

nasdaq_price = nasdaq.history(period=None)
sp500_price = sp500.history(period=None)

nasdaq_price = nasdaq_price.iloc[-len(data):,:]
sp500_price = sp500_price.iloc[-len(data):,:]
data.tail()
# Out:
#                  Close
# Date
# 2023-10-09  259.670013
# 2023-10-10  263.619995
# 2023-10-11  262.989990
# 2023-10-12  258.869995
# 2023-10-13  251.119995

# %%
print(f'Total records are {data.shape[0]}. \nNull check \n{data.isnull().count()}')
# Out:
# Total records are 64.
# Null check
# Close    64
# dtype: int64

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(data['Close'], label='Tesla Closing Price', color='g')
ax1.set_xlabel('Date')
ax1.set_ylabel('Tesla Closing Price', color='g')
ax1.tick_params(axis='y', labelcolor='g')
ax1.grid(True)

ax2 = ax1.twinx()
ax2.plot(nasdaq_price['Close'], label='Nasdaq', color='b')
ax2.set_ylabel('Nasdaq Index', color='b')
ax2.tick_params(axis='y', labelcolor='b')

ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.plot(sp500_price['Close'], label='S&P 500', color='r')
ax3.set_ylabel('S&P 500 Index', color='r')
ax3.tick_params(axis='y', labelcolor='r')

fig.tight_layout()
plt.title('Stock Prices & Indices (10 years)')
plt.show()

# %% [markdown]
# Other technical indicators and metrics that can help with prediction.
#
# 1. Moving Average Convergence Divergence (MACD) -
# 2. Relative Strength Index (RSI) - _Result of stock price_
# 3. On-Balance Volume (OBV) - _Perhaps doesn't align with short term strategy_
# 4. Chaikin Money Flow(CMF) - _Perhaps doesn't align with short term strategy_
# 5. Fibonacci Retracements
# 6. News Sentiment Analysis
# 7. and more...
#
# A few consideration for the algorithm are.
# 1. Not to short a equity (or till model are in higher confidence) to limit potential losses.
# 2. RSI below 30 should trigger a higher aggressive technical
# 3. Crossover of MACD line should trigger a higher aggressive technical. Recommended to wait for 3-4 days to confirm __NOT__ a false positive
# 4. Fibonacci Retracements should support a slightly higher aggressive technical on each level. Most commonly used ratios include 23.6%, 38.2%, 50%, 61.8%, and 78.6
#
# These pointers are what humans can observe. Using deep learning algorithms (RNN-LSTM), more pattern could potentially be uncovered.

# %%
#MACD with traditional setting (26/12/9). The signal line is a nine-period EMA of the MACD line.
def compute_macd(data, short_window=12, long_window=26, signal_window=9):
    data = data.copy()
    short_ema = data['Close'].ewm(span=short_window, adjust=False).mean()
    long_ema = data['Close'].ewm(span=long_window, adjust=False).mean()
    
    # MACD line
    data.loc[:, 'MACD'] = short_ema - long_ema
    # Signal Line
    data.loc[:, 'Signal_Line'] = data['MACD'].ewm(span=signal_window, adjust=False).mean()

    return data

data = compute_macd(data)
data.head()
# Out:
#                  Close      MACD  Signal_Line
# Date
# 2023-07-17  290.380005  0.000000     0.000000
# 2023-07-18  293.339996  0.236125     0.047225
# 2023-07-19  291.260010  0.252507     0.088281
# 2023-07-20  262.899994 -1.999873    -0.329350
# 2023-07-21  260.019989 -3.971512    -1.057782

# %%
#RSI with Exponential Weighted Function(ewm) which give weights to values.
def compute_rsi(data, window):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).fillna(0)
    loss = (-delta.where(delta < 0, 0)).fillna(0)

    avg_gain = gain.ewm(min_periods=window, adjust=False, alpha=1/window).mean()
    avg_loss = loss.ewm(min_periods=window, adjust=False, alpha=1/window).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    return rsi

data['RSI'] = compute_rsi(data['Close'], 14)
data.head() # Notice the first 13 rows RSI are NaN due to calculation window
# Out:
#                  Close      MACD  Signal_Line  RSI
# Date
# 2023-07-17  290.380005  0.000000     0.000000  NaN
# 2023-07-18  293.339996  0.236125     0.047225  NaN
# 2023-07-19  291.260010  0.252507     0.088281  NaN
# 2023-07-20  262.899994 -1.999873    -0.329350  NaN
# 2023-07-21  260.019989 -3.971512    -1.057782  NaN

# %%
# 3 months period plot
# Plotting MACD and stock price
end_date = data.index[-1]  # Get the last date
start_date = end_date - timedelta(days=90)  # approx. 3 months

filtered_data = data[start_date:end_date]

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.set_xlabel('Date')
ax1.set_ylabel('MACD & Signal Line', color='tab:blue')
ax1.plot(filtered_data.index, filtered_data['MACD'], label='MACD', color='blue')
ax1.plot(filtered_data.index, filtered_data['Signal_Line'], label='Signal Line', color='red')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc='upper left')

ax2 = ax1.twinx()  
ax2.set_ylabel('Stock Price', color='tab:green')  
ax2.plot(filtered_data.index, filtered_data['Close'], label='Stock Price', color='green')
ax2.tick_params(axis='y', labelcolor='tab:green')

plt.title('MACD, Signal Line & Stock Price for the Last 3 Months')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
fig.tight_layout()  
plt.show()

# %%
# Plotting RSI and stock price
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.set_xlabel('Date')
ax1.set_ylabel('RSI', color='tab:blue')
ax1.plot(filtered_data.index, filtered_data['RSI'], label='RSI', color='blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylim(0, 100)
ax1.legend(loc='upper left')
ax1.axhline(y=70, color='darkred', linestyle='--')  # Overbought level
ax1.axhline(y=30, color='darkgreen', linestyle='--')  # Oversold level

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Stock Price', color='tab:green')  # we already handled the x-label with ax1
ax2.plot(filtered_data.index, filtered_data['Close'], label='Stock Price', color='green')
ax2.tick_params(axis='y', labelcolor='tab:green')

plt.title('RSI & Stock Price for the Last 3 Months')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
fig.tight_layout()  # Adjust subplot parameters to give specified padding
plt.show()

# %%
print(f'Total records are {data.shape[0]}. \nNull check \n{data.isnull().sum()}')
# Out:
# Total records are 64.
# Null check
# Close           0
# MACD            0
# Signal_Line     0
# RSI            13
# dtype: int64

# %%
correlation_matrix = data.corr()
correlation_matrix
# Out:
#                 Close      MACD  Signal_Line       RSI
# Close        1.000000  0.658053     0.598434  0.842510
# MACD         0.658053  1.000000     0.902601  0.814545
# Signal_Line  0.598434  0.902601     1.000000  0.580965
# RSI          0.842510  0.814545     0.580965  1.000000

# %%
# Using Seaborn to plot a heatmap
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# We can note from the seaborn plot that MACD, Signal Line and RSI are all good features to be used to predict 'Close' price. For a simple approach, we will be using just the 'Closing' price for LSTM.

# %% [markdown]
# ### Part 3. ML techniques and data partition
# Recurrent Neural Networks (RNNs) are designed to handle sequences of variable lengths, making them particularly suitable for tasks like predicting future values in a sequence. They maintain an internal state that can capture information about previous elements in the sequence, allowing them to remember important parts and potentially forget less crucial details over time.
#
#
# However, traditional RNNs suffer from challenges related to the vanishing and exploding gradient problems, especially when processing long sequences. These issues hinder RNN’s ability to learn from distant past information in the sequence.
#
#
# To address this, __Long Short-Term Memory (LSTM)__ networks were introduced. LSTMs are a special kind of RNN that can learn and remember over long sequences and are not as susceptible to the vanishing gradient problem as standard RNNs. This makes them more efficient at capturing long-term dependencies in sequence data.
#
# Allocation of data for training are
# 1. Train: 80%
# 2. Test: Last 5 days will be used for testing.
# 3. Validation: Takes the rest
#
# Project is a regression problem, hence we will be testing out performance metrics.
# 1. Mean Square Error (MSE)

# %%
data = data[['Close']]

# %%
# 2. Preprocess the Data
scaler = MinMaxScaler(feature_range=(-1, 1))
data_normalized = scaler.fit_transform(data['Close'].values.reshape(-1, 1))#.values.reshape(-1, 1))

# Convert data to PyTorch tensors and create in/out sequence data
def create_inout_sequences(input_data, tw):
    inout_seq = []
    L = len(input_data)
    for i in range(L-tw):
        train_seq = input_data[i:i+tw]
        train_label = input_data[i+tw:i+tw+1]
        inout_seq.append((train_seq, train_label))
    return inout_seq

train_window = 5
inout_seq = create_inout_sequences(data_normalized, train_window)
inout_seq = [(torch.FloatTensor(seq), torch.FloatTensor(label)) for seq, label in inout_seq]

# Split data into train, validate, and test sets
total_length = len(inout_seq)
test_length = 5
remaining_length = total_length - test_length

train_length = int(0.9 * remaining_length)
valid_length = remaining_length - train_length

train_dataset = inout_seq[:train_length]
valid_dataset = inout_seq[train_length:train_length+valid_length]
test_dataset = inout_seq[-test_length:]

# %%
# 3. Build LSTM Model - Pytorch
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.linear(out[:, -1, :])
        return out
    
    
def main(train_window, train_dataset, valid_dataset, test_dataset, bo) :
    input_dim = 1
    hidden_dim = int(bo[0])
    num_layers = int(bo[1])
    output_dim = 1

    dropout = float(bo[2]) #0.01
    learning_rate = float(bo[3]) #0.01
    epochs = int(bo[4])
    
    model = LSTM(input_dim, hidden_dim, num_layers, dropout, output_dim)
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    # Training loop
    for epoch in range(epochs):
        model.train()
        train_losses = []
        for seq, labels in train_dataset:
            optimizer.zero_grad()
            y_pred = model(seq.view(1, train_window, -1))
            loss = criterion(y_pred, labels)
            train_losses.append(loss.item())
            loss.backward()
            optimizer.step()
        avg_train_loss = np.mean(train_losses)
        
        # Validation
        model.eval()
        valid_losses = []
        for seq, labels in valid_dataset:
            with torch.no_grad():
                y_pred = model(seq.view(1, train_window, -1))
                loss = criterion(y_pred, labels)
                valid_losses.append(loss.item())
        avg_valid_loss = np.mean(valid_losses)
        
        if epoch % 10 == 0:
            print(f'Epoch {epoch}/{epochs} - Training loss: {avg_train_loss:.4f}, Validation loss: {avg_valid_loss:.4f}')

    # Testing for the last 5 days
    test_inputs = data_normalized[-test_length:].tolist()
    model.eval()
    for _ in range(test_length):  # Predicting for next 5 days
        seq = torch.FloatTensor(test_inputs[-train_window:]).view(1, train_window, -1)
        with torch.no_grad():
            test_inputs.append([model(seq).item()])

    actual_predictions = scaler.inverse_transform(np.array(test_inputs[train_window:]).reshape(-1, 1))
    dates = data.index[-test_length:]
    plt.figure(figsize=(15, 6))
    plt.plot(dates, actual_predictions, label='Predicted', color='red')
    plt.plot(dates, scaler.inverse_transform(data_normalized[-5:]), label='Actual', color='blue')
    plt.title("TSLA Stock Price Prediction vs Actual for the last 5 days")
    plt.xlabel("Date")
    plt.ylabel("Stock Price")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return(actual_predictions)
    
if __name__ == '__main__':
    bo = [64, 2, 0.3, 0.01, 30]     # hidden_dim, num_layers, dropout, learning_rate, epoch
    actual_predictions = main(train_window, train_dataset, valid_dataset, test_dataset, bo) 
    print(actual_predictions)
# Out:
# Epoch 0/30 - Training loss: 0.1159, Validation loss: 0.0220
# Epoch 10/30 - Training loss: 0.0988, Validation loss: 0.0214
# Epoch 20/30 - Training loss: 0.0471, Validation loss: 0.0193
# [[252.7337595 ]
#  [252.17668009]
#  [252.71932958]
#  [253.4621727 ]
#  [254.49177917]]

# %%
actual_predictions, data.tail(len(actual_predictions))
abs_different = np.sum(abs(actual_predictions-data.tail(len(actual_predictions))))
print(f'Sum of 5 windows differents from predicted with actual : {abs_different.values}')
# Out:
# Sum of 5 windows differents from predicted with actual : [37.42983608]

# %% [markdown]
# ### Part 3. Hyperparameter Optimization
#
# From the plot above, we can observe that the prediction is pretty bad. Options is to try to tune the parameters to see if plots can get closer to the actual test.
#
# From the high validation loss, we can conclude that the the model is overfitting.
#
# Bayesian Optimization

# %%
from statistics import NormalDist
from scipy.stats import norm
from sklearn.decomposition import KernelPCA, PCA

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
X = np.array(bo)
Y = np.array(abs_different) # val_loss # Validation loss
X = X.reshape(1, -1)  
Y = Y.reshape(-1, 1)  
print(X.shape,Y.shape)
X,Y
# Out:
# (1, 5) (1, 1)
# (array([[6.4e+01, 2.0e+00, 3.0e-01, 1.0e-02, 3.0e+01]]),
#  array([[37.42983608]]))

# %% [markdown]
# A combination of 3 acquistion functions and picking the highest values for the nexy query point. The aim of this BO is to seek a global minima

# %%
#PI
def probability_improvement(eta): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_layers = np.linspace(2, 3, 2)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.0001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_layers, 
                       query_range_dropout, query_range_lr, query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T

    mean, std = bogp.predict(query_points, return_std=True)
    best_observed = np.min(df_y) #.max(df_y) 
    
    pi = []
    for k in range(len(query_points)):
        pi.append(1 - NormalDist(mu = mean[k], sigma = std[k]).cdf(best_observed - eta))
        
    pi = np.array(pi)
    next_query_point = query_points[np.argmin(pi)] #[np.argmax(pi)]
    
    return query_points, pi 

#UCB
def upper_confidence_bound(beta): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_layers = np.linspace(2, 3, 2)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_layers, 
                       query_range_dropout, query_range_lr, query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T

    mean, std = bogp.predict(query_points, return_std=True)
    ucb = mean - (beta * std)
    
    next_query_point = query_points[np.argmin(ucb)] # [np.argmax(ucb)]
    
    return query_points, ucb 

#EI
def expected_improvement(xi): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_layers = np.linspace(2, 3, 2)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.0001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_layers, 
                       query_range_dropout, query_range_lr,query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T
    
    f_best = np.min(df_y)
    mean, std = bogp.predict(query_points, return_std=True)
    
    z = (f_best - mean - xi) / std #    z = (mean - f_best - xi) / std
    ei = (f_best - mean - xi) * norm.cdf(z) - std * norm.pdf(z)# ei = (mean - f_best - xi) * norm.cdf(z) + std * norm.pdf(z)
    ei[std == 0.0] = 0.0  # Set EI to 0 where std is 0 to avoid division by zero.

    next_query_point = query_points[np.argmax(ei)] # This is correct

    return query_points, ei

# %%
# stack new query and observation for every loop
def update_surrogate_model(new_X, new_y):
    if len(X) == 0 and len(Y) == 0:
        # If X and Y are empty, just return the new_X and new_y
        return new_X, new_y

    # Stack them vertically
    df_X = np.vstack([X, new_X])
    df_y = np.vstack([Y, new_y])
    return df_X, df_y

# Picking the highest acquisition function value among UCB, EI and PI.
def choose_next_query_point(next_query_point_ucb, af_ucb, next_query_point_ei, af_ei, next_query_point_pi, af_pi):
    
    # Find the index of the element with the highest acquisition function value for each method
    min_ucb_index = np.argmin(af_ucb)
    min_pi_index = np.argmin(af_pi)
    max_ei_index = np.argmax(af_ei)

    # Get the corresponding query points with the highest acquisition function values
    next_query_point_min_ucb = next_query_point_ucb[min_ucb_index]
    next_query_point_max_ei = next_query_point_ei[max_ei_index]
    next_query_point_min_pi = next_query_point_pi[min_pi_index]


    # Compare the acquisition function values and choose the highest
    if af_ucb[min_ucb_index] <= af_ei[max_ei_index] and af_ucb[min_ucb_index] <= af_pi[min_pi_index]:
        return next_query_point_min_ucb, 'UCB'
    
    elif af_ei[max_ei_index] >= af_ucb[min_ucb_index] and af_ei[max_ei_index] >= af_pi[min_pi_index]:
        return next_query_point_max_ei, 'Expected Improvement'
    
    else:
        return next_query_point_min_pi, 'Probability of Improvement'

# %%
query = np.empty((0, len(X[0])))  # Assuming X is a 2D array
obs = np.empty((0, 1))  # 1D column vector

noise_assumption = 1e-10
rbf_lengthscale = 0.1
beta = 1.96        # UCB exploration parameter. beta increases, exploration increases.
eta = 0.1         # PI exploration parameter. 0.1 for explore, 0.01 for exploitiation
xi = 0.1          # EI exploration parameter. 0.1  for balance, 0.01 for exploitiation

# Fit the Gaussian Process Regression model
kernel = RBF(length_scale=rbf_lengthscale*len(X.T))
bogp = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption, n_restarts_optimizer=5)

breakcount = 0

while breakcount < 20 :
    if breakcount == 10:
        beta = 1
        eta = 0.01
        xi = 0.01
        
    # Update the surrogate model with the new observation
    df_X, df_y = update_surrogate_model(query, obs)
    X = df_X
    Y = df_y
    
    # Fit the surrogate model with the given dataset
    bogp.fit(df_X, df_y)

    # # Get the next suggested query point
    next_query_point_ucb, af_ucb = upper_confidence_bound(beta)
    next_query_point_pi, af_pi = probability_improvement(eta)
    next_query_point_ei, af_ei = expected_improvement(xi)

    # # Comparing 3 aq. function and choose the highest.
    next_query_point, chosen_af = choose_next_query_point(next_query_point_ucb, af_ucb, next_query_point_ei, af_ei, next_query_point_pi, af_pi)

    print(f'Next suggested query point by {chosen_af}: '
          f'{np.round(next_query_point[0], 0):.0f}, '
          f'{np.round(next_query_point[1], 0):.0f}, '
          f'{np.round(next_query_point[2], 1):.1f}, '
          f'{np.round(next_query_point[3], 3):.3f}, '
          f'{np.round(next_query_point[4], 0):.0f}')
    print(df_X, df_y)
    bo = next_query_point #For bo hidden_dim, num_layers, dropout, learning_rate, epoch

    actual_predictions = main(train_window, train_dataset, valid_dataset, test_dataset, bo) 
    abs_different = np.sum(abs(actual_predictions-data.tail(len(actual_predictions))))
    query = np.array(bo).reshape(1, -1)
    obs = np.array(abs_different) # val_loss # Validation loss
    
    print(f'BO is {query}, with loss of {obs}')
    
    breakcount +=1
    if abs_different.iloc[-1] < 5:
        break
# Out:
# Next suggested query point by UCB: 64, 2, 0.2, 0.001, 40
# [[6.4e+01 2.0e+00 3.0e-01 1.0e-02 3.0e+01]] [[37.42983608]]
# Epoch 0/40 - Training loss: 0.1769, Validation loss: 0.0237
# Epoch 10/40 - Training loss: 0.0501, Validation loss: 0.0230
# Epoch 20/40 - Training loss: 0.0415, Validation loss: 0.0241
# Epoch 30/40 - Training loss: 0.0366, Validation loss: 0.0226
# BO is [[6.4e+01 2.0e+00 2.0e-01 1.0e-03 4.0e+01]], with loss of [43.23961516]
# Next suggested query point by UCB: 288, 2, 0.2, 0.001, 30
# [[6.4e+01 2.0e+00 3.0e-01 1.0e-02 3.0e+01]
#  [6.4e+01 2.0e+00 2.0e-01 1.0e-03 4.0e+01]] [[37.42983608]
#  [43.23961516]]
# Epoch 0/30 - Training loss: 0.1422, Validation loss: 0.0220
# Epoch 10/30 - Training loss: 0.0558, Validation loss: 0.0209
# Epoch 20/30 - Training loss: 0.0358, Validation loss: 0.0205
# BO is [[2.88e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]], with loss of [39.51005559]
# Next suggested query point by UCB: 512, 2, 0.2, 0.001, 30
# [[6.40e+01 2.00e+00 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 4.00e+01]
#  [2.88e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]] [[37.42983608]
#  [43.23961516]
#  [39.51005559]]
# Epoch 0/30 - Training loss: 0.0997, Validation loss: 0.0247
# Epoch 10/30 - Training loss: 0.0621, Validation loss: 0.0201
# Epoch 20/30 - Training loss: 0.0400, Validation loss: 0.0182
# BO is [[5.12e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]], with loss of [47.79516189]
# Next suggested query point by UCB: 64, 2, 0.2, 0.001, 50
# [[6.40e+01 2.00e+00 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 4.00e+01]
#  [2.88e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [5.12e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]] [[37.42983608]
#  [43.23961516]
#  [39.51005559]
#  [47.79516189]]
# Epoch 0/50 - Training loss: 0.1706, Validation loss: 0.0291
# Epoch 10/50 - Training loss: 0.0471, Validation loss: 0.0241
# Epoch 20/50 - Training loss: 0.0395, Validation loss: 0.0216
# Epoch 30/50 - Training loss: 0.0384, Validation loss: 0.0248
# Epoch 40/50 - Training loss: 0.0347, Validation loss: 0.0229
# BO is [[6.4e+01 2.0e+00 2.0e-01 1.0e-03 5.0e+01]], with loss of [43.41147517]
# Next suggested query point by UCB: 288, 3, 0.5, 0.100, 100
# [[6.40e+01 2.00e+00 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 4.00e+01]
#  [2.88e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [5.12e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 5.00e+01]] [[37.42983608]
#  [43.23961516]
#  [39.51005559]
#  [47.79516189]
#  [43.41147517
Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Epoch 0/80 - Training loss: 0.1648, Validation loss: 0.0316
# Epoch 10/80 - Training loss: 0.0441, Validation loss: 0.0244
# Epoch 20/80 - Training loss: 0.0375, Validation loss: 0.0246
# Epoch 30/80 - Training loss: 0.0324, Validation loss: 0.0240
# Epoch 40/80 - Training loss: 0.0312, Validation loss: 0.0199
# Epoch 50/80 - Training loss: 0.0323, Validation loss: 0.0223
# Epoch 60/80 - Training loss: 0.0303, Validation loss: 0.0198
# Epoch 70/80 - Training loss: 0.0271, Validation loss: 0.0254
# BO is [[6.4e+01 2.0e+00 2.0e-01 1.0e-03 8.0e+01]], with loss of [64.11736144]
# Next suggested query point by UCB: 64, 2, 0.2, 0.001, 90
# [[6.40e+01 2.00e+00 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 4.00e+01]
#  [2.88e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [5.12e+02 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 5.00e+01]
#  [2.88e+02 3.00e+00 5.00e-01 1.00e-01 1.00e+02]
#  [5.12e+02 3.00e+00 5.00e-01 1.00e-01 1.00e+02]
#  [6.40e+01 3.00e+00 5.00e-01 1.00e-01 1.00e+02]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 6.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 7.00e+01]
#  [5.12e+02 2.00e+00 2.00e-01 1.00e-04 6.00e+01]
#  [2.88e+02 3.00e+00 5.00e-01 1.00e-01 5.00e+01]
#  [5.12e+02 2.00e+00 2.00e-01 1.00e-04 1.00e+02]
#  [2.88e+02 2.00e+00 2.00e-01 1.00e-03 7.00e+01]
#  [5.12e+02 3.00e+00 5.00e-01 1.00e-01 8.00e+01]
#  [5.12e+02 3.00e+00 5.00e-01 1.00e-01 5.00e+01]
#  [2.88e+02 3.00e+00 5.00e-01 1.00e-01 4.00e+01]
#  [2.88e+02 3.00e+00 2.00e-01 1.00e-01 4.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 3.00e+01]
#  [6.40e+01 2.00e+00 2.00e-01 1.00e-03 8.00e+01]] [[ 37.42983608]
#  [ 43.23961516]
#  [ 39.51005559]
#  [ 47.79516189]
#  [ 43.41147517]
#  [ 77.41676541]
#  [ 36.66639269]
#  [ 94.11671216]
#  [ 43.89741696]
#  [ 53.22348041]
#  [ 57.27967004]
#  [ 40.07420583]
#  [ 44.93805599]
#  [ 98.73264571]
#  [134.08579212]
#  [ 70.8651445 ]
#  [ 23.24524557]
#  [110.96282587]
#  [ 52.72011416]
#  [ 64.11736144]]
# Epoch 0/90 - Training loss: 0.1788, Validation loss: 0.0265
# Epoch 10/90 - Training loss: 0.0513, Validation loss: 0.0267
# Epoch 20/90 - Training loss: 0.0361, Validation loss: 0.0215
# Epoch 30/90 - Training loss: 0.0364, Validation loss: 0.0233
# Epoch 40/90 - Training loss: 0.0312, Validation loss: 0.0226
# Epoch 50/90 - Training loss: 0.0410, Validation loss: 0.0251
# Epoch 60/90 - Training loss: 0.0281, Validation loss: 0.0248
# Epoch 70/90 - Training loss: 0.0269, Validation loss: 0.0292
# Epoch 80/90 - Training loss: 0.0245, Validation loss: 0.0262
# BO is [[6.4e+01 2.0e+00 2.0e-01 1.0e-03 9.0e+01]], with loss of [56.57715536]

# %%
plt.figure(figsize=(15, 6))
plt.plot(df_y, marker='o', linestyle='-', color='b')
plt.title('Pytorch BO visualisation')
plt.xlabel('epoch')
plt.ylabel('score')
plt.grid(True)
plt.show()

# %% [markdown]
# From the results obtained from 50 queries, It is noted that.
#
# 1. The most similar trend between predicted and actual are from bo = [288, 2, 0.2, 0.001, 80].
#
# 2. The lowest different are from bo = [64.   2.   0.2  0.1 30. ]. However, the predicted lines are almost a straight line instead of following the trend.
#
# We do not want the lowest score as a straight line doesn't provide any information of where the trend is heading to. Instead, we should opt for option 1.

# %% [markdown]
# Lets try TensorFlow instead of python. Fixing a layer of 2.
#
# ### TensorFlow LSTM

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam


train_window = 5
inout_seq = create_inout_sequences(data_normalized, train_window)
total_length = len(inout_seq)

train_length = int(0.8 * (total_length-5))
valid_length = total_length - 5 - train_length

train_dataset = inout_seq[:train_length]
valid_dataset = inout_seq[train_length:train_length+valid_length]
test_dataset = inout_seq[-5:]

train_x = np.array([item[0] for item in train_dataset])
train_y = np.array([item[1] for item in train_dataset])
valid_x = np.array([item[0] for item in valid_dataset])
valid_y = np.array([item[1] for item in valid_dataset])

class PrintLossCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs is not None:
            if epoch % 10 == 0:
                print(f'Epoch {epoch}/{self.params["epochs"]} - Training loss: {logs["loss"]:.4f}, Validation loss: {logs["val_loss"]:.4f}')
                
                
def main_tf(train_x, train_y, valid_x, valid_y, test_dataset, bo):
    
    hidden_dim = int(bo[0])
    dropout = float(bo[1]) #0.01
    learning_rate = float(bo[2])
    epoch = int(bo[3])
    
    model = Sequential()
    model.add(LSTM(hidden_dim, activation='relu', input_shape=(train_window, 1), return_sequences=True))
    model.add(Dropout(dropout))
    model.add(LSTM(hidden_dim, activation='relu', return_sequences=False))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate = learning_rate)
    model.compile(optimizer=optimizer, loss=MeanSquaredError())

    history = model.fit(train_x, train_y, epochs=epoch, 
                        validation_data=(valid_x, valid_y), verbose=1, callbacks=[PrintLossCallback()])

    # Plotting training and validation loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.show()

    test_x = np.array([item[0] for item in test_dataset])
    test_y = np.array([item[1] for item in test_dataset])

    predictions = model.predict(test_x)
    actual_predictions = scaler.inverse_transform(predictions)
    dates = data.index[-5:]

    plt.figure(figsize=(15, 6))
    plt.plot(dates, actual_predictions, label='Predicted', color='red')
    plt.plot(dates, scaler.inverse_transform(test_y.reshape(-1, 1)), label='Actual', color='blue')
    plt.title("TSLA Stock Price Prediction vs Actual")
    plt.xlabel("Date")
    plt.ylabel("Stock Price")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return(actual_predictions)
    
if __name__ == '__main__':

    bo = [64, 0.3, 0.01, 30]     # hidden_dim, dropout, learning rate, epoch
    actual_predictions = main_tf(train_x, train_y, valid_x, valid_y, test_dataset, bo) 
    print(actual_predictions)
# Out:
# Epoch 1/30
# 1/2 [==============>...............] - ETA: 2s - loss: 0.1627Epoch 0/30 - Training loss: 0.1455, Validation loss: 0.0401
# 2/2 [==============================] - 3s 442ms/step - loss: 0.1455 - val_loss: 0.0401
# Epoch 2/30
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1032 - val_loss: 0.0594
# Epoch 3/30
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0800 - val_loss: 0.0950
# Epoch 4/30
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0976 - val_loss: 0.0788
# Epoch 5/30
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0762 - val_loss: 0.0692
# Epoch 6/30
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0736 - val_loss: 0.0606
# Epoch 7/30
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0760 - val_loss: 0.0529
# Epoch 8/30
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0742 - val_loss: 0.0509
# Epoch 9/30
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0708 - val_loss: 0.0522
# Epoch 10/30
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0697 - val_loss: 0.0534
# Epoch 11/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0530Epoch 10/30 - Training loss: 0.0527, Validation loss: 0.0593
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0527 - val_loss: 0.0593
# Epoch 12/30
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0503 - val_loss: 0.0476
# Epoch 13/30
# 2/2 [==============================] - 0s 55ms/step - loss: 0.0519 - val_loss: 0.0451
# Epoch 14/30
# 2/2 [==============================] - 0s 57ms/step - loss: 0.0534 - val_loss: 0.0526
# Epoch 15/30
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0571 - val_loss: 0.0398
# Epoch 16/30
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0463 - val_loss: 0.0432
# Epoch 17/30
# 2/2 [==============================] - 0s 50ms/step - loss: 0.0574 - val_loss: 0.0499
# Epoch 18/30
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0512 - val_loss: 0.0491
# Epoch 19/30
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0526 - val_loss: 0.0422
# Epoch 20/30
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0487 - val_loss: 0.0392
# Epoch 21/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0534Epoch 20/30 - Training loss: 0.0731, Validation loss: 0.0362
# 2/2 [==============================] - 0s 51ms/step - loss: 0.0731 - val_loss: 0.0362
# Epoch 22/30
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0456 - val_loss: 0.0546
# Epoch 23/30
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0511 - val_loss: 0.0663
# Epoch 24/30
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0544 - val_loss: 0.0481
# Epoch 25/30
# 2/2 [==============================] - 0s 61ms/step - loss: 0.0559 - val_loss: 0.0468
# Epoch 26/30
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0361 - val_loss: 0.0500
# Epoch 27/30
# 2/2 [==============================] - 0s 59ms/step - loss: 0.0478 - val_loss: 0.0466
# Epoch 28/30
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0444 - val_loss: 0.0517
# Epoch 29/30
# 2/2 [==============================] - 0s 58ms/step - loss: 0.0409 - val_loss: 0.0501
# Epoch 30/30
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0517 - val_loss: 0.0354
# 1/1 [==============================] - 0s 345ms/step
# [[258.9158 ]
#  [259.26068]
#  [259.1343 ]
#  [259.7657 ]
#  [259.09018]]

# %%
X = np.array(bo)
Y = np.array(abs_different) # val_loss # Validation loss
X = X.reshape(1, -1)  
Y = Y.reshape(-1, 1)  
print(X.shape,Y.shape)
X,Y
# Out:
# (1, 4) (1, 1)
# (array([[6.4e+01, 3.0e-01, 1.0e-02, 3.0e+01]]), array([[213.33428955]]))

# %%
#PI
def probability_improvement(eta): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_dropout, 
                       query_range_lr, query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T

    mean, std = bogp.predict(query_points, return_std=True)
    best_observed = np.min(df_y) #.max(df_y) 
    
    pi = []
    for k in range(len(query_points)):
        pi.append(1 - NormalDist(mu = mean[k], sigma = std[k]).cdf(best_observed - eta))
        
    pi = np.array(pi)
    next_query_point = query_points[np.argmin(pi)] #[np.argmax(pi)]
    
    return query_points, pi 

#UCB
def upper_confidence_bound(beta): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_dropout, 
                       query_range_lr, query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T

    mean, std = bogp.predict(query_points, return_std=True)
    ucb = mean - (beta * std)
    
    next_query_point = query_points[np.argmin(ucb)] # [np.argmax(ucb)]
    
    return query_points, ucb 

#EI
def expected_improvement(xi): 
    #For bo hidden_dim, num_layers, dropout, learning_rate
    query_range_hiddenunit = np.linspace(64, 512, 3)  
    query_range_dropout = np.linspace(0.2, 0.5, 4)    
    query_range_lr = np.linspace(0.001, 0.1, 4)    
    query_range_epoch = np.linspace(30, 100, 8)
    
    
    # Construct meshgrid using individual feature ranges
    grid = np.meshgrid(query_range_hiddenunit, query_range_dropout, 
                       query_range_lr, query_range_epoch)
    query_points = np.vstack(list(map(np.ravel, grid))).T
    
    f_best = np.min(df_y)
    mean, std = bogp.predict(query_points, return_std=True)
    
    z = (f_best - mean - xi) / std #    z = (mean - f_best - xi) / std
    ei = (f_best - mean - xi) * norm.cdf(z) - std * norm.pdf(z)# ei = (mean - f_best - xi) * norm.cdf(z) + std * norm.pdf(z)
    ei[std == 0.0] = 0.0  # Set EI to 0 where std is 0 to avoid division by zero.

    next_query_point = query_points[np.argmax(ei)] # This is correct

    return query_points, ei

# %%
query = np.empty((0, len(X[0])))  # Assuming X is a 2D array
obs = np.empty((0, 1))  # 1D column vector

noise_assumption = 1e-10
rbf_lengthscale = 0.1
beta = 1.96        # UCB exploration parameter. beta increases, exploration increases.
eta = 0.1         # PI exploration parameter. 0.1 for explore, 0.01 for exploitiation
xi = 0.1          # EI exploration parameter. 0.1  for balance, 0.01 for exploitiation

# Fit the Gaussian Process Regression model
kernel = RBF(length_scale=rbf_lengthscale*len(X.T))
bogp = GaussianProcessRegressor(kernel = kernel, alpha=noise_assumption, n_restarts_optimizer=5)

breakcount = 0

while breakcount < 20 :
    if breakcount == 10:
        beta = 1
        eta = 0.01
        xi = 0.01
        
    # Update the surrogate model with the new observation
    df_X, df_y = update_surrogate_model(query, obs)
    X = df_X
    Y = df_y
    
    # Fit the surrogate model with the given dataset
    bogp.fit(df_X, df_y)

    # # Get the next suggested query point
    next_query_point_ucb, af_ucb = upper_confidence_bound(beta)
    next_query_point_pi, af_pi = probability_improvement(eta)
    next_query_point_ei, af_ei = expected_improvement(xi)

    # # Comparing 3 aq. function and choose the highest.
    next_query_point, chosen_af = choose_next_query_point(next_query_point_ucb, af_ucb, next_query_point_ei, af_ei, next_query_point_pi, af_pi)

    print(f'Next suggested query point by {chosen_af}: '
          f'{np.round(next_query_point[0], 0):.0f}, '
          f'{np.round(next_query_point[1], 0):.0f}, '
          f'{np.round(next_query_point[2], 3):.3f}, '
          f'{np.round(next_query_point[3], 0):.0f}')

    print(df_X, df_y)
    bo = next_query_point #For bo hidden_dim, learning_rate, epoch

    actual_predictions = main_tf(train_x, train_y, valid_x, valid_y, test_dataset, bo)
    abs_different = np.sum(abs(actual_predictions-data.tail(len(actual_predictions))))
    query = np.array(bo).reshape(1, -1)
    obs = np.array(abs_different) # val_loss # Validation loss
    
    print(f'BO is {query}, with loss of {obs}')
    
    breakcount +=1
    if abs_different.iloc[-1] < 5:
        break
# Out:
# Next suggested query point by UCB: 64, 0, 0.001, 40
# [[6.4e+01 3.0e-01 1.0e-02 3.0e+01]] [[213.33428955]]
# Epoch 1/40
# 1/2 [==============>...............] - ETA: 2s - loss: 0.1813Epoch 0/40 - Training loss: 0.1573, Validation loss: 0.0424
# 2/2 [==============================] - 3s 346ms/step - loss: 0.1573 - val_loss: 0.0424
# Epoch 2/40
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1518 - val_loss: 0.0423
# Epoch 3/40
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1478 - val_loss: 0.0420
# Epoch 4/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1429 - val_loss: 0.0417
# Epoch 5/40
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1375 - val_loss: 0.0414
# Epoch 6/40
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1339 - val_loss: 0.0414
# Epoch 7/40
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1263 - val_loss: 0.0419
# Epoch 8/40
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1208 - val_loss: 0.0427
# Epoch 9/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1175 - val_loss: 0.0439
# Epoch 10/40
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1107 - val_loss: 0.0456
# Epoch 11/40
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0879Epoch 10/40 - Training loss: 0.1010, Validation loss: 0.0483
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1010 - val_loss: 0.0483
# Epoch 12/40
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0950 - val_loss: 0.0517
# Epoch 13/40
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0904 - val_loss: 0.0561
# Epoch 14/40
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0863 - val_loss: 0.0615
# Epoch 15/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0776 - val_loss: 0.0675
# Epoch 16/40
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0747 - val_loss: 0.0740
# Epoch 17/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0730 - val_loss: 0.0803
# Epoch 18/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0756 - val_loss: 0.0846
# Epoch 19/40
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0669 - val_loss: 0.0869
# Epoch 20/40
# 2/2 [==============================] - 0s 38ms/step - loss: 0.
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0513 - val_loss: 0.0488
# Epoch 50/80
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0472 - val_loss: 0.0487
# Epoch 51/80
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0621Epoch 50/80 - Training loss: 0.0550, Validation loss: 0.0478
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0550 - val_loss: 0.0478
# Epoch 52/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0560 - val_loss: 0.0467
# Epoch 53/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0496 - val_loss: 0.0456
# Epoch 54/80
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0463 - val_loss: 0.0450
# Epoch 55/80
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0511 - val_loss: 0.0443
# Epoch 56/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0475 - val_loss: 0.0438
# Epoch 57/80
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0463 - val_loss: 0.0433
# Epoch 58/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0479 - val_loss: 0.0422
# Epoch 59/80
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0500 - val_loss: 0.0417
# Epoch 60/80
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0578 - val_loss: 0.0415
# Epoch 61/80
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0418Epoch 60/80 - Training loss: 0.0512, Validation loss: 0.0421
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0512 - val_loss: 0.0421
# Epoch 62/80
# 2/2 [==============================] - 0s 46ms/step - loss: 0.0512 - val_loss: 0.0422
# Epoch 63/80
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0440 - val_loss: 0.0410
# Epoch 64/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0423 - val_loss: 0.0395
# Epoch 65/80
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0502 - val_loss: 0.0385
# Epoch 66/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0484 - val_loss: 0.0378
# Epoch 67/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0503 - val_loss: 0.0378
# Epoch 68/80
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0450 - val_loss: 0.0392
# Epoch 69/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0450 - val_loss: 0.0419
# Epoch 70/80
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0436 - val_loss: 0.0452
# Epoch 71/80
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0476Epoch 70/80 - Training loss: 0.0473, Validation loss: 0.0469
# 2/2 [==============================] - 0s 44ms/step - loss: 0.0473 - val_loss: 0.0469
# Epoch 72/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0440 - val_loss: 0.0429
# Epoch 73/80
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0426 - val_loss: 0.0397
# Epoch 74/80
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0419 - val_loss: 0.0389
# Epoch 75/80
# 2/2 [==============================] - 0s 43ms/step - loss: 0.0502 - val_loss: 0.0393
# Epoch 76/80
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0488 - val_loss: 0.0410
# Epoch 77/80
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0386 - val_loss: 0.0420
# Epoch 78/80
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0422 - val_loss: 0.0421
# Epoch 79/80
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0384 - val_loss: 0.0413
# Epoch 80/80
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0341 - val_loss: 0.0402
# 1/1 [==============================] - 0s 257ms/step
# BO is [[6.4e+01 2.0e-01 1.0e-03 8.0e+01]], with loss of [18.2706604]
# Next suggested query point by UCB: 288, 0, 0.001, 30
# [[6.4e+01 3.0e-01 1.0e-02 3.0e+01]
#  [6.4e+01 2.0e-01 1.0e-03 4.0e+01]
#  [6.4e+01 2.0e-01 1.0e-03 5.0e+01]
#  [6.4e+01 2.0e-01 1.0e-03 6.0e+01]
#  [6.4e+01 2.0e-01 1.0e-03 7.0e+01]
#  [6.4e+01 2.0e-01 1.0e-03 8.0e+01]] [[213.33428955]
#  [ 23.74980164]
#  [ 22.95890808]
#  [ 18.84771729]
#  [ 19.20620728]
#  [ 18.2706604 ]]
# Epoch 1/30
# 1/2 [==============>...............] - ETA: 2s - loss: 0.1594Epoch 0/30 - Training loss: 0.1517, Validation loss: 0.0420
# 2/2 [==============================] - 3s 349ms/step - loss: 0.1517 - val_loss: 0.0420
# Epoch 2/30
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1358 - val_loss: 0.0430
# Epoch 3/30
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1198 - val_loss: 0.0464
# Epoch 4/30
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1033 - val_loss: 0.0549
# Epoch 5/30
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0848 - val_loss: 0.0700
# Epoch 6/30
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0741 - val_loss: 0.0872
# Epoch 7/30
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0701 - val_loss: 0.0933
# Epoch 8/30
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0722 - val_loss: 0.0835
# Epoch 9/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0689 - val_loss: 0.0690
# Epoch 10/30
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0669 - val_loss: 0.0584
# Epoch 11/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0677Epoch 10/30 - Training loss: 0.0612, Validation loss: 0.0522
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0612 - val_loss: 0.0522
# Epoch 12/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0606 - val_loss: 0.0481
# Epoch 13/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0631 - val_loss: 0.0470
# Epoch 14/30
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0598 - val_loss: 0.0475
# Epoch 15/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0614 - val_loss: 0.0489
# Epoch 16/30
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0544 - val_loss: 0.0505
# Epoch 17/30
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0508 - val_loss: 0.0516
# Epoch 18/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0507 - val_loss: 0.0557
# Epoch 19/30
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0594 - val_loss: 0.0558
# Epoch 20/30
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0639 - val_loss: 0.0491
# Epoch 21/30
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0519Epoch 20/30 - Training loss: 0.0495, Validation loss: 0.0524
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0495 - val_loss: 0.0524
# Epoch 22/30
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0476 - val_loss: 0.0539
# Epoch 23/30
# 2/2 [==============================] - 0s 66ms/step - loss: 0.0539 - val_loss: 0.0467
# Epoch 24/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0506 - val_loss: 0.0396
# Epoch 25/30
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0425 - val_loss: 0.0371
# Epoch 26/30
# 2/2 [==============================] - 0s 65ms/step - loss: 0.0444 - val_loss: 0.0374
# Epoch 27/30
# 2/2 [==============================] - 0s 67ms/step - loss: 0.0503 - val_loss: 0.0409
# Epoch 28/30
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0444 - val_loss: 0.0405
# Epoch 29/30
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0434 - val_loss: 0.0381
# Epoch 30/30
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0398 - val_loss: 0.0363
# 1/1 [==============================] - 0s 264ms/step
# BO is [[2.88e+02 2.00e-01 1.00e-03 3.00e+01]], with loss of [17.72320557]
# Next suggested query point by UCB: 64, 0, 0.001, 90
# [[6.40e+01 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 4.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 5.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 6.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 7.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 8.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 3.00e+01]] [[213.33428955]
#  [ 23.74980164]
#  [ 22.95890808]
#  [ 18.84771729]
#  [ 19.20620728]
#  [ 18.2706604 ]
#  [ 17.72320557]]
# Epoch 1/90
# 1/2 [==============>...............] - ETA: 3s - loss: 0.1653Epoch 0/90 - Training loss: 0.1543, Validation loss: 0.0413
# 2/2 [==============================] - 4s 446ms/step - loss: 0.1543 - val_loss: 0.0413
# Epoch 2/90
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1493 - val_loss: 0.0408
# Epoch 3/90
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1443 - val_loss: 0.0406
# Epoch 4/90
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1380 - val_loss: 0.0405
# Epoch 5/90
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1312 - val_loss: 0.0406
# Epoch 6/90
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1249 - val_loss: 0.0411
# Epoch 7/90
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1198 - val_loss: 0.0417
# Epoch 8/90
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1122 - val_loss: 0.0426
# Epoch 9/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1059 - val_loss: 0.0440
# Epoch 10/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0997 - val_loss: 0.0464
# Epoch 11/90
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0897Epoch 10/90 - Training loss: 0.0910, Validation loss: 0.0499
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0910 - val_loss: 0.0499
# Epoch 12/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0847 - val_loss: 0.0544
# Epoch 13/90
# 2/2 [==============================] - 0s 40ms/step - loss: 0.0824 - val_loss: 0.0598
# Epoch 14/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0737 - val_loss: 0.0654
# Epoch 15/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0756 - val_loss: 0.0709
# Epoch 16/90
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0720 - val_loss: 0.0755
# Epoch 17/90
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0740 - val_loss: 0.0786
# Epoch 18/90
# 2/2 [==============================] - 0s 49ms/step - loss: 0.0733 - val_loss: 0.0794
# Epoch 19/90
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0706 - val_loss: 0.0787
# Epoch 20/90
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0724 - val_loss: 0.0763
# Epoch 21/90
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0681Epoch 20/90 - Training loss: 0.0644, Validation loss: 0.0737
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0644 - val_loss: 0.0737
# Epoch 22/90
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0702 - val_loss: 0.0709
# Epoch 23/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0617 - val_loss: 0.0678
# Epoch 24/90
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0636 - val_loss: 0.0654
# Epoch 25/90
# 2/2 [==============================] - 0s 53ms/step - loss: 0.0639 - val_loss: 0.0631
# Epoch 26/90
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0694 - val_loss: 0.0610
# Epoch 27/90
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0659 - val_loss: 0.0594
# Epoch 28/90
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0657 - val_loss: 0.0585
# Epoch 29/90
# 2/2 [==============================] - 0s 41ms/step - loss: 0.0637 - val_loss: 0.0581
# Epoch 30/90
# 2/2 [==============================] - 0s 39ms/step - loss: 0.
100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0293 - val_loss: 0.0277
# Epoch 90/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0368 - val_loss: 0.0261
# Epoch 91/100
# 2/2 [==============================] - ETA: 0s - loss: 0.0322Epoch 90/100 - Training loss: 0.0322, Validation loss: 0.0257
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0322 - val_loss: 0.0257
# Epoch 92/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0348 - val_loss: 0.0296
# Epoch 93/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0332 - val_loss: 0.0345
# Epoch 94/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0319 - val_loss: 0.0330
# Epoch 95/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0281 - val_loss: 0.0316
# Epoch 96/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0333 - val_loss: 0.0309
# Epoch 97/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0360 - val_loss: 0.0274
# Epoch 98/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0277 - val_loss: 0.0241
# Epoch 99/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0312 - val_loss: 0.0272
# Epoch 100/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0333 - val_loss: 0.0347
# 1/1 [==============================] - 0s 376ms/step
# BO is [[5.12e+02 2.00e-01 1.00e-03 1.00e+02]], with loss of [17.89334106]
# Next suggested query point by UCB: 512, 0, 0.001, 60
# [[6.40e+01 3.00e-01 1.00e-02 3.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 4.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 5.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 6.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 7.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 8.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 3.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 9.00e+01]
#  [6.40e+01 2.00e-01 1.00e-03 1.00e+02]
#  [2.88e+02 2.00e-01 1.00e-03 4.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 5.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 6.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 7.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 8.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 9.00e+01]
#  [5.12e+02 2.00e-01 1.00e-03 3.00e+01]
#  [2.88e+02 2.00e-01 1.00e-03 1.00e+02]
#  [5.12e+02 2.00e-01 1.00e-03 4.00e+01]
#  [5.12e+02 2.00e-01 1.00e-03 5.00e+01]
#  [5.12e+02 2.00e-01 1.00e-03 1.00e+02]] [[213.33428955]
#  [ 23.74980164]
#  [ 22.95890808]
#  [ 18.84771729]
#  [ 19.20620728]
#  [ 18.2706604 ]
#  [ 17.72320557]
#  [ 17.41723633]
#  [ 17.81121826]
#  [ 18.04769897]
#  [ 17.2628479 ]
#  [ 16.91564941]
#  [ 18.05160522]
#  [ 17.78665161]
#  [ 18.1697998 ]
#  [ 17.95809937]
#  [ 17.9239502 ]
#  [ 17.23986816]
#  [ 17.48678589]
#  [ 17.89334106]]
# Epoch 1/60
# 2/2 [==============================] - ETA: 0s - loss: 0.1518Epoch 0/60 - Training loss: 0.1518, Validation loss: 0.0421
# 2/2 [==============================] - 3s 442ms/step - loss: 0.1518 - val_loss: 0.0421
# Epoch 2/60
# 2/2 [==============================] - 0s 130ms/step - loss: 0.1255 - val_loss: 0.0461
# Epoch 3/60
# 2/2 [==============================] - 0s 131ms/step - loss: 0.0961 - val_loss: 0.0642
# Epoch 4/60
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0722 - val_loss: 0.1105
# Epoch 5/60
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0839 - val_loss: 0.1022
# Epoch 6/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0757 - val_loss: 0.0694
# Epoch 7/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0650 - val_loss: 0.0540
# Epoch 8/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0630 - val_loss: 0.0507
# Epoch 9/60
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0610 - val_loss: 0.0499
# Epoch 10/60
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0619 - val_loss: 0.0464
# Epoch 11/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0578Epoch 10/60 - Training loss: 0.0578, Validation loss: 0.0465
# 2/2 [==============================] - 0s 134ms/step - loss: 0.0578 - val_loss: 0.0465
# Epoch 12/60
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0547 - val_loss: 0.0500
# Epoch 13/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0516 - val_loss: 0.0580
# Epoch 14/60
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0506 - val_loss: 0.0651
# Epoch 15/60
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0531 - val_loss: 0.0506
# Epoch 16/60
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0428 - val_loss: 0.0427
# Epoch 17/60
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0509 - val_loss: 0.0388
# Epoch 18/60
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0466 - val_loss: 0.0461
# Epoch 19/60
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0491 - val_loss: 0.0463
# Epoch 20/60
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0473 - val_loss: 0.0377
# Epoch 21/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0425Epoch 20/60 - Training loss: 0.0425, Validation loss: 0.0357
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0425 - val_loss: 0.0357
# Epoch 22/60
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0478 - val_loss: 0.0383
# Epoch 23/60
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0419 - val_loss: 0.0453
# Epoch 24/60
# 2/2 [==============================] - 0s 128ms/step - loss: 0.0410 - val_loss: 0.0466
# Epoch 25/60
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0434 - val_loss: 0.0446
# Epoch 26/60
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0438 - val_loss: 0.0371
# Epoch 27/60
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0362 - val_loss: 0.0334
# Epoch 28/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0371 - val_loss: 0.0325
# Epoch 29/60
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0436 - val_loss: 0.0311
# Epoch 30/60
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0373 - val_loss: 0.0284
# Epoch 31/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0392Epoch 30/60 - Training loss: 0.0392, Validation loss: 0.0327
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0392 - val_loss: 0.0327
# Epoch 32/60
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0377 - val_loss: 0.0399
# Epoch 33/60
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0457 - val_loss: 0.0323
# Epoch 34/60
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0387 - val_loss: 0.0301
# Epoch 35/60
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0436 - val_loss: 0.0314
# Epoch 36/60
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0358 - val_loss: 0.0404
# Epoch 37/60
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0452 - val_loss: 0.0326
# Epoch 38/60
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0355 - val_loss: 0.0258
# Epoch 39/60
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0407 - val_loss: 0.0268
# Epoch 40/60
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0398 - val_loss: 0.0322
# Epoch 41/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0413Epoch 40/60 - Training loss: 0.0413, Validation loss: 0.0422
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0413 - val_loss: 0.0422
# Epoch 42/60
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0372 - val_loss: 0.0344
# Epoch 43/60
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0332 - val_loss: 0.0311
# Epoch 44/60
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0387 - val_loss: 0.0322
# Epoch 45/60
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0341 - val_loss: 0.0409
# Epoch 46/60
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0407 - val_loss: 0.0422
# Epoch 47/60
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0346 - val_loss: 0.0330
# Epoch 48/60
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0360 - val_loss: 0.0307
# Epoch 49/60
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0372 - val_loss: 0.0303
# Epoch 50/60
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0378 - val_loss: 0.0320
# Epoch 51/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0359Epoch 50/60 - Training loss: 0.0359, Validation loss: 0.0303
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0359 - val_loss: 0.0303
# Epoch 52/60
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0332 - val_loss: 0.0287
# Epoch 53/60
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0374 - val_loss: 0.0296
# Epoch 54/60
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0343 - val_loss: 0.0333
# Epoch 55/60
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0391 - val_loss: 0.0325
# Epoch 56/60
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0318 - val_loss: 0.0303
# Epoch 57/60
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0380 - val_loss: 0.0298
# Epoch 58/60
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0335 - val_loss: 0.0343
# Epoch 59/60
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0300 - val_loss: 0.0391
# Epoch 60/60
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0443 - val_loss: 0.0358
# 1/1 [==============================] - 0s 333ms/step
# BO is [[5.12e+02 2.00e-01 1.00e-03 6.00e+01]], with loss of [18.56271362]

# %%
plt.figure(figsize=(15, 6))
plt.plot(df_y, marker='o', linestyle='-', color='b')
plt.title('TensorFlow BO visualisation')
plt.xlabel('epoch')
plt.ylabel('score')
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusion
#
# One question comes to mind when predicting stock market. Is stock price a causation or consequence?
#
# This project doesn't consider...
# 1. Transaction cost
# 2. Slippage
# 3.
